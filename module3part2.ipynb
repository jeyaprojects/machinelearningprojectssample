# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
Raw_Housing_Data = pd.read_csv('Raw_Housing_Prices3.csv')

# %%
#module 4

# %%
Raw_Housing_Data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
#"zipcode" is int(sometimes there will be high price in particular zipcode)

# %%
#it would make sense to convert zipcode to categorical datatype-->saleprice in each zipcoade acan be analysed
#variables across zipcode acan be seen

# %%
#we convert this datatype to verify

# %%
Raw_Housing_Data["Zipcode"]=Raw_Housing_Data["Zipcode"].astype(object)

# %%
#lets chk the datatype

# %%
Raw_Housing_Data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                       object
# Latitude                                     float64
# ...

# %%
#zipcode is convertred to object

# %%
#now look at "no og time visited" is object,its says how many time that house was visited(once,thrice,twice..)
#if we convert to numerical valuse it make sense,to find relationsip betweeen sale price and no of time visited

# %%
#to recode the variable
#1-->to find all unique values present in the variable
#2-->replace the unique values with corresponding values

# %%
#lets chk uniqu values

# %%
Raw_Housing_Data["No of Times Visited"].unique()#it has change after mapping before it was once,none,thrice,twice,four
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
#lets create a mapping between old and new values (we use dictionary)

# %%
mapping = {"None":"0",
         "Once": "1",
         "Twice":"2",
         "Thrice":"3",
         "Four":"4"}

# %%
Raw_Housing_Data["No of Times Visited"]=Raw_Housing_Data["No of Times Visited"].map(mapping)

# %%
#lets verify the changes

# %%
Raw_Housing_Data["No of Times Visited"].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
Raw_Housing_Data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21604   263000018         14 May 2017    360000.0               3
# 21605  6600060120    15 February 2016    400000.0               4
# 21606  1523300141        14 June 2017    402101.0               2
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
#now lets look at "renovated house " vaiable(is says whether the house is renovated or not).this will impact the sale price(newly renovated house will have high price than old one)

# %%
#here we need to derive two variables from "Renovated House"
#1-->"ever renovated"-->we list the renovated house
#2-->"year since renovated"

# %%
#"Ever renovated"-->assign "yes"(if it is renovted) and "No" for "renovate year " is zero-->this is numerical variable
#this is called "categorical variables"{after derive this 2 variable we need to add them in our dataset}

# %%
#we use where() of numpylibrary

# %%
Raw_Housing_Data["Ever Renovate"]=np.where(Raw_Housing_Data["Renovated Year"] == 0 ,'No','Yes')

# %%
Raw_Housing_Data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Basement Area (in Sqft)  \
# 0              No                   0  ...                       0
# ...

# %%
#for second variable-->"Year Since Renovation"="year of sale" -"Year of Renovation"
#"Year of Sale"-->we get it from when house was sold
#for the house which is never renovated ,"Year since Renovation"-->becomes zero(0)
#"Year Since Renovation " is numerical  variables

# %%
#we need to fetch "year" from "Date house was sold" and name it as"purchase year

# %%
Raw_Housing_Data["Purchase Year"]=pd.DatetimeIndex(Raw_Housing_Data['Date House was Sold']).year

# %%
#"Year Since Renovation"="Year of Sale"-"Year of renovation"

# %%
Raw_Housing_Data["Years Since Renovation"]=np.where(Raw_Housing_Data['Ever Renovated']=='Yes',abs(Raw_Housing_Data['Purchase Year']-Raw_Housing_Data['Renovated Year']),0)

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
#to verify

# %%
Raw_Housing_Data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Renovated Year  Zipcode  Latitude  \
# ...

# %%
#one step to do

# %%
#we used "Date house was sold" -->to get "Purchase year"
#we used "Purchased year " and  "Renovated Year "-->to get "Year Since Renovation"
#"Year since Renovation" will be used for analyisi and model bulding going forward
#now our dataset look tidy(unwanted column->"Date hose was sold","purcahse Year","Renovated year") need to be removed
#we use drop function

# %%
Raw_Housing_Data.drop(columns=["Purchase Year","Date House was Sold","Renovated Year","Ever Renovate"],inplace=True)

# %%
#to verify

# %%
Raw_Housing_Data
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21604   263000018    360000.0               3             2.50
# 21605  6600060120    400000.0               4             2.50
# 21606  1523300141    402101.0               2             0.75
# 21607   291310100    400000.0               3             2.50
# 21608  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0                   1180.0              5650.0           1.0              No
# ...

# %%
Raw_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Sale Price                                 21609 non-null  float64
#  2   No of Bedrooms                             21609 non-null  int64
#  3   No of Bathrooms                            21609 non-null  float64
#  4   Flat Area (in Sqft)                        21609 non-null  float64
#  5   Lot Area (in Sqft)                         21609 non-null  float64
#  6   No of Floors                               21609 non-null  float64
#  7   Waterfront View                            21609 non-null  object
#  8   No of Times Visited                        21609 non-null  object
#  9   Condition of the House                     21609 non-null  object
# ...

# %%
Raw_Housing_Data.to_csv("Transformed_Housing_Data",index = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 Transformed_Housing_Data.info()
#
# NameError: name 'Transformed_Housing_Data' is not defined
